# %% [markdown]
# # Preparación Datos

# %%
# Data handling
import numpy as np
import pandas as pd
import os
pd.set_option('display.max_columns', None)


import glob
import json

# Data visualization
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import seaborn as sns
import missingno as mso
import matplotlib.ticker as ticker
import geopandas as gpd

import ydata_profiling as pp
from sklearn import cluster, mixture
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans, DBSCAN, OPTICS
from sklearn.preprocessing import StandardScaler
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.neighbors import kneighbors_graph
from itertools import cycle, islice

import plotly as py
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
from nltk import tokenize,stem
import holoviews as hv
from holoviews import opts
hv.extension('bokeh')
import hvplot.pandas
from tabulate import tabulate

# Stats
from statsmodels.graphics.gofplots import qqplot
from scipy.stats import shapiro, norm
# warnings
import warnings
warnings.filterwarnings('ignore')
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="d8849a29-5abc-4dc5-a1c2-c0dff7e4d081" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
# Lee el archivo CSV en un DataFrame
df = pd.read_csv('dataset_completo.csv')

# %%
# Convierte la columna que contiene la fecha en un formato de fecha
df['Date'] = pd.to_datetime(df['DataAccadimento'])

# Extrae el año, mes, día de la semana y día del mes de la fecha
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month
df['Day_of_week'] = df['Date'].dt.day_name()
df['Day_of_month'] = df['Date'].dt.day
df.head()
# Out:
#   DataRilevazione DataProtocollo DataAccadimento DataDefinizione DataMorte  \
# 0      30/04/2023     18/06/2018      17/06/2018      28/06/2018       NaN
# 1      30/04/2023     04/10/2021      30/09/2021      27/10/2021       NaN
# 2      30/04/2023     28/09/2020      23/09/2020      14/11/2020       NaN
# 3      30/04/2023     06/04/2022      04/04/2022      22/04/2022       NaN
# 4      30/04/2023     21/02/2020      19/02/2020      17/03/2020       NaN
#
#    LuogoAccadimento  IdentificativoInfortunato Genere  Eta LuogoNascita  \
# 0                69                    3895603      M   41         ITAL
# 1                66                    3882671      M   61         ITAL
# 2                66                    3897622      M   52         ITAL
# 3                69                    3896347      F   49         ITAL
# 4                68                    3894028      M   69         ITAL
#
#   ModalitaAccadimento ConSenzaMezzoTrasporto  IdentificativoCaso  \
# ...

# %%
df.columns = ['FechaEncuesta', 'FechaRegistro', 'FechaAccidente', 'FechaDefiniciónAdmin', 'FechaMuerte', 'Provincia', 'CódigoInterno',
              'Género', 'Edad', 'LugarNacimiento', 'ModalidadAccidente', 'ImplicaciónMedioTransporte', 'IdentificativoCaso', 'SituaciónAdmin',
              'DefAdminEvidienciaMortal', 'Indemnización', 'DecisiónInstrucciónResultadoMortal', 'GradoDeterioro', 'DíasIndemnizados', 
              'IdentificadorEmpleador', 'PosiciónAseguramientoTerritorial', 'DetalleActividadEconómica', 'Gestión', 'TipoActividadEconómica', 
              'SectorEconómico', 'Fecha', 'Año', 'Mes', 'DiaSemana', 'DiaMes']

# %%
df.columns
# Out:
# Index(['FechaEncuesta', 'FechaRegistro', 'FechaAccidente',
#        'FechaDefiniciónAdmin', 'FechaMuerte', 'Provincia', 'CódigoInterno',
#        'Género', 'Edad', 'LugarNacimiento', 'ModalidadAccidente',
#        'ImplicaciónMedioTransporte', 'IdentificativoCaso', 'SituaciónAdmin',
#        'DefAdminEvidienciaMortal', 'Indemnización',
#        'DecisiónInstrucciónResultadoMortal', 'GradoDeterioro',
#        'DíasIndemnizados', 'IdentificadorEmpleador',
#        'PosiciónAseguramientoTerritorial', 'DetalleActividadEconómica',
#        'Gestión', 'TipoActividadEconómica', 'SectorEconómico', 'Fecha', 'Año',
#        'Mes', 'DiaSemana', 'DiaMes'],
#       dtype='object')

# %%
conteo_valores = df['GradoDeterioro'].value_counts()

# Imprimir el resultado
print('Número de veces que aparece cada valor único en GradoDeterioro:')
print(conteo_valores)
# Out:
# Número de veces que aparece cada valor único en GradoDeterioro:
# GradoDeterioro
# -1     2802570
#  2       63394
#  3       47000
#  6       43615
#  4       39823
#         ...
#  98          2
#  76          2
#  81          2
#  99          1
#  83          1
# Name: count, Length: 99, dtype: int64

# %%
df = df[df['GradoDeterioro'] != -1]
df.shape
# Out:
# (326877, 30)

# %%
conteo_edad_menos_uno = df['Edad'].value_counts().get(-1, 0)

print(f"La cantidad de veces que 'Edad' es igual a -1 es: {conteo_edad_menos_uno}")
# Out:
# La cantidad de veces que 'Edad' es igual a -1 es: 11

# %%
df = df[df['Edad'] != -1]
df.shape
# Out:
# (326866, 30)

# %%
media_grado_deterioro = df['GradoDeterioro'].mean()

print(f"La media de 'GradoDeterioro' es: {media_grado_deterioro}")
# Out:
# La media de 'GradoDeterioro' es: 6.677210232939492

# %%
territorial_codes = pd.read_csv('Codici-statistici-e-denominazioni.csv', sep=";", encoding = "ISO-8859-1")
territorial_codes.head()
# Out:
#    Codice Regione  \
# 0               1
# 1               1
# 2               1
# 3               1
# 4               1
#
#    Codice dell'Unità territoriale sovracomunale \n(valida a fini statistici)  \
# 0                                                201
# 1                                                201
# 2                                                201
# 3                                                201
# 4                                                201
#
#    Codice Provincia (Storico)(1)  Progressivo del Comune (2)  \
# 0                              1                           1
# 1                              1                           2
# 2                              1                           3
# 3                              1                           4
# 4                              1                           6
#
#    Codice Comune formato alfanumerico Denominazione (Italiana e straniera)  \
# ...

# %%
territorial_codes.columns = ['region code', 'Code of the supra-municipal territorial unit', 'Province Code (Historical)', 'Municipality progressive',
                            'Municipality code in alphanumeric format', 'Name (Italian and foreign)', 'Name in Italian', 'Name in other language',
                            'Code Geographical Distribution', 'Geographical distribution', 'Region Name', 'Name of the supra-municipal territorial unit',
                            'Type of supra-municipal territorial unit', 'Flag Provincial capital / metropolitan city / free consortium',
                            'Automotive abbreviation', 'Municipal code numeric format', 'Numeric municipality code with 110 provinces (from 2010 to 2016)',
                            'Numeric municipality code with 107 provinces (from 2006 to 2009)', 'Numeric municipality code with 103 provinces (1995 to 2005)',
                            'Cadastral code of the municipality', 'NUTS1 code 2010', 'NUTS2 code 2010', 'NUTS3 code 2010', 'NUTS1 code 2021', 'NUTS2 code 2021',
                            'NUTS3 code 2021']

# %%
code_province_name_region = pd.concat([territorial_codes['Province Code (Historical)'],
                                     territorial_codes['Automotive abbreviation'],
                                     territorial_codes['Region Name']], axis = 1)

# %%
# When the province is Naples, the abbreviation is NA. This is read as a missing value, replace NA with 'NAPOLI' in full:
code_province_name_region['Automotive abbreviation'][code_province_name_region['Automotive abbreviation'].isna()] = 'NAPOLI' 
code_province_name_region.columns = ['PlaceOfOccurrence', 'abbreviation', 'Region']

code_province_name_region = code_province_name_region.drop_duplicates()

# %%
# merge accident data with ISTAT data
data = pd.merge(df, code_province_name_region, left_on='Provincia', right_on='PlaceOfOccurrence', how='left')
data.head()
# Out:
#   FechaEncuesta FechaRegistro FechaAccidente FechaDefiniciónAdmin FechaMuerte  \
# 0    30/04/2023    10/05/2018     08/05/2018           23/05/2018         NaN
# 1    30/04/2023    14/05/2018     12/05/2018           05/02/2019         NaN
# 2    30/04/2023    03/05/2021     29/04/2021           02/09/2021         NaN
# 3    30/04/2023    01/08/2019     26/07/2019           04/03/2020         NaN
# 4    30/04/2023    04/10/2022     03/10/2022           03/11/2022         NaN
#
#    Provincia  CódigoInterno Género  Edad LugarNacimiento ModalidadAccidente  \
# 0         68       28161406      M    52            ITAL                  N
# 1         69       28124291      F    62            ITAL                  S
# 2         68       10719778      M    62            ITAL                  N
# 3         69        3896101      F    80            ITAL                  N
# 4         69       28215423      F    57            ITAL                  N
#
# ...

# %%
data_TipoActividadEconómica = pd.read_csv("GestioneTariffaria.csv", sep = ";", encoding = "ISO-8859-1")
print(data_TipoActividadEconómica)
# Out:
#   GestioneTariffaria DescrGestioneTariffaria
# 0                  1               Industria
# 1                  2             Artigianato
# 2                  3               Terziario
# 3                  4          Altre Attività
# 4                 ND         Non determinata

# %%
data_TipoActividadEconómica.columns = ["TipoActividadEconómica", "DescrTipoActividadEconómica"]
data1 = pd.merge(data, data_TipoActividadEconómica, on='TipoActividadEconómica', how='left')

# %%
data_DetalleActividadEconómica = pd.read_csv("SettoreAttivitaEconomica.csv", sep = ";", encoding = "ISO-8859-1")
data_DetalleActividadEconómica.head()
# Out:
#   SettoreAttivitaEconomica                                         DescrAteco  \
# 0                     N 80              Servizi di vigilanza e investigazione
# 1                     N 81       Attivita' di servizi per edifici e paesaggio
# 2                     N 82  Attivita' di supporto per le funzioni d'uffici...
# 3                       ND                                    Non determinato
# 4                     O 84  Amministrazione pubblica e difesa, assicurazio...
#
#   CodiceAtecoLiv1                                     DescrAtecoLiv1
# 0               N  Noleggio, agenzie di viaggio, servizi di suppo...
# 1               N  Noleggio, agenzie di viaggio, servizi di suppo...
# 2               N  Noleggio, agenzie di viaggio, servizi di suppo...
# 3              ND                                    Non determinato
# 4               O  Amministrazione pubblica e difesa, assicurazio...

# %%
data2 = pd.merge(data1, data_DetalleActividadEconómica, left_on='DetalleActividadEconómica', right_on='SettoreAttivitaEconomica', how='left')
data2.head()
# Out:
#   FechaEncuesta FechaRegistro FechaAccidente FechaDefiniciónAdmin FechaMuerte  \
# 0    30/04/2023    10/05/2018     08/05/2018           23/05/2018         NaN
# 1    30/04/2023    14/05/2018     12/05/2018           05/02/2019         NaN
# 2    30/04/2023    03/05/2021     29/04/2021           02/09/2021         NaN
# 3    30/04/2023    01/08/2019     26/07/2019           04/03/2020         NaN
# 4    30/04/2023    04/10/2022     03/10/2022           03/11/2022         NaN
#
#    Provincia  CódigoInterno Género  Edad LugarNacimiento ModalidadAccidente  \
# 0         68       28161406      M    52            ITAL                  N
# 1         69       28124291      F    62            ITAL                  S
# 2         68       10719778      M    62            ITAL                  N
# 3         69        3896101      F    80            ITAL                  N
# 4         69       28215423      F    57            ITAL                  N
#
# ...

# %%
data_SectorEconómico = pd.read_csv("GrandeGruppoTariffario.csv", sep = ";", encoding = "ISO-8859-1")
print(data_SectorEconómico)
# Out:
#    GrandeGruppoTariffario   DescrGrandeGruppoTariffario
# 0                       1  GG1 Lav. agricole e alimenti
# 1                       2     GG2 Chimica, carta e cuoi
# 2                       3    GG3 Costruzioni e impianti
# 3                       4   GG4 Energia e comunicazioni
# 4                       5            GG5 Legno e affini
# 5                       6      GG6 Metalli e macchinari
# 6                       7  GG7 Mineraria, rocce e vetro
# 7                       8      GG8 Tessile e confezioni
# 8                       9     GG9 Trasporti e magazzini
# 9                       0            GG0 Attività varie
# 10                     ND             X Non determinato

# %%
data_SectorEconómico.columns = ["SectorEconómico", "DescrSectorEconómico"]

# %%
data3 = pd.merge(data2, data_SectorEconómico, on='SectorEconómico', how='left')
data3.head()
# Out:
#   FechaEncuesta FechaRegistro FechaAccidente FechaDefiniciónAdmin FechaMuerte  \
# 0    30/04/2023    10/05/2018     08/05/2018           23/05/2018         NaN
# 1    30/04/2023    14/05/2018     12/05/2018           05/02/2019         NaN
# 2    30/04/2023    03/05/2021     29/04/2021           02/09/2021         NaN
# 3    30/04/2023    01/08/2019     26/07/2019           04/03/2020         NaN
# 4    30/04/2023    04/10/2022     03/10/2022           03/11/2022         NaN
#
#    Provincia  CódigoInterno Género  Edad LugarNacimiento ModalidadAccidente  \
# 0         68       28161406      M    52            ITAL                  N
# 1         69       28124291      F    62            ITAL                  S
# 2         68       10719778      M    62            ITAL                  N
# 3         69        3896101      F    80            ITAL                  N
# 4         69       28215423      F    57            ITAL                  N
#
# ...

# %%
conteo_SectorX = data3['DescrSectorEconómico'].value_counts()

# Imprimir el resultado
print('Número de veces que aparece cada valor único en DescrSectorEconómico:')
print(conteo_SectorX)
# Out:
# Número de veces que aparece cada valor único en DescrSectorEconómico:
# DescrSectorEconómico
# GG0 Attività varie              122172
# X Non determinato                63901
# GG3 Costruzioni e impianti       43873
# GG6 Metalli e macchinari         35841
# GG9 Trasporti e magazzini        26028
# GG1 Lav. agricole e alimenti     10565
# GG2 Chimica, carta e cuoi         8747
# GG5 Legno e affini                5620
# GG7 Mineraria, rocce e vetro      4446
# GG8 Tessile e confezioni          4328
# GG4 Energia e comunicazioni       1345
# Name: count, dtype: int64

# %%
data3 = data3[data3['DescrSectorEconómico'] != 'X Non determinato']
data3.shape
# Out:
# (262965, 39)

# %%
DescrTipoActividadEconómica_ = {'Non determinata': 'No Determinada',
                           'Industria':'Industria',
                           'Altre Attività':'Otra Actividad',
                           'Artigianato': 'Artesanía',
                           'Terziario':'Terciario'}
                           
data3['DescrTipoActividadEconómica']=data3['DescrTipoActividadEconómica'].map(DescrTipoActividadEconómica_)

# %%
# Diccionario de mapeo para 'SectorEconómico'
DescrSectorEconómico_ = {'GG9 Trasporti e magazzini': 'Transporte y almacenamiento', 'X Non determinato': 'No Determinado', 
                         'GG0 Attività varie': 'Actividades diversas', 'GG6 Metalli e macchinari': 'Metales y maquinaria', 
                         'GG3 Costruzioni e impianti': 'Construcción e instalaciones', 'GG1 Lav. agricole e alimenti': 'Agricultura y alimentación', 
                         'GG8 Tessile e confezioni': 'Textil y confección', 'GG2 Chimica, carta e cuoi': 'Química, papel y cuero', 
                         'GG5 Legno e affini': 'Madera y afines', 'GG7 Mineraria, rocce e vetro': 'Minería, rocas y vidrio', 
                         'GG4 Energia e comunicazioni': 'Energía y comunicaciones'}

# Aplicar el mapeo a la columna 'SectorEconómico'
data3['DescrSectorEconómico'] = data3['DescrSectorEconómico'].map(DescrSectorEconómico_)

# %%
data3 = data3.fillna(0)

# %%
# Crear un diccionario que mapea los intervalos a las clases definidas en el texto
intervalos = {
    (1, 5): "def. micropermanentes",
    (6, 15): "def. entidad mínima",
    (16, 25): "def. menor gravedad media",
    (26, 50): "def. mayor gravedad media",
    (51, 85): "macrodeficiencias permanentes",
    (86, 100): "macrodeficiencias anulan buena salud"
}

# Crear una nueva columna en tu DataFrame que contenga las clases
data3['ClaseDeterioro'] = pd.cut(data3['GradoDeterioro'], bins=[0, 5, 15, 25, 50, 85, 100], labels=list(intervalos.values()), include_lowest=True)

# %%
data3['Muerte'] = data3['FechaMuerte'].apply(lambda fecha: 1 if fecha != 0 else 0)

# %%
# Group by 'Año' and count occurrences of 'Muerte' equal to 1
muerte_counts = data3[data3['Muerte'] == 1].groupby('Año').size().reset_index(name='Número de Muertes')

# Create a bar chart
plt.style.use('seaborn-whitegrid') 
plt.figure(figsize=(5, 4))
plt.bar(muerte_counts['Año'], muerte_counts['Número de Muertes'], color='#4169E1')
plt.xlabel('Año')
plt.ylabel('Número de Muertes')
plt.title('Número de Muertes por Año')
plt.grid(False)
plt.show()

# %%
# Group by 'Año' and count occurrences of 'Muerte' equal to 1
muerte_counts = data3[data3['Muerte'] == 1].groupby('Año').size().reset_index(name='Número de Muertes')

# Create a bar chart
plt.style.use('seaborn-whitegrid') 
plt.figure(figsize=(6, 4))

# Bar chart with integer x-axis ticks
plt.bar(muerte_counts['Año'], muerte_counts['Número de Muertes'], color='#4169E1')

# Set integer ticks on both x and y axes
plt.xticks(muerte_counts['Año'].astype(int))
plt.yticks(range(0, int(muerte_counts['Número de Muertes'].max()) + 1, 5))


plt.xlabel('Año')
plt.ylabel('Número de Muertes')
plt.title('Número de Muertes por Año')
plt.grid(False)
plt.show()

# %%
cantidad_muertes = data3['Muerte'].sum()

# Imprimir el resultado
print(f'Número de 1 en la columna "Muerte": {cantidad_muertes}')
# Out:
# Número de 1 en la columna "Muerte": 58

# %%
italy = gpd.read_file('ProvCM01012021_g_WGS84.shp') # shape files

# %%
italy = italy.rename(columns = {'SIGLA':'abbreviation'})

# %%
data.abbreviation[data.abbreviation.isna()] = 'NAPOLI'

italy.abbreviation[italy.abbreviation == 'NA'] = 'NAPOLI'

merge = italy.merge(data3, on='abbreviation', how='right')
merge.head()
# Out:
#    COD_RIP  COD_REG  COD_PROV  COD_CM  COD_UTS  DEN_PROV DEN_CM   DEN_UTS  \
# 0        4       13        68       0       68   Pescara      -   Pescara
# 1        4       13        69       0       69    Chieti      -    Chieti
# 2        4       13        68       0       68   Pescara      -   Pescara
# 3        4       13        66       0       66  L'Aquila      -  L'Aquila
# 4        4       13        68       0       68   Pescara      -   Pescara
#
#   abbreviation   TIPO_UTS     Shape_Leng    Shape_Area  \
# 0           PE  Provincia  204779.051207  1.228774e+09
# 1           CH  Provincia  263886.995445  2.599087e+09
# 2           PE  Provincia  204779.051207  1.228774e+09
# 3           AQ  Provincia  471499.171546  5.047085e+09
# 4           PE  Provincia  204779.051207  1.228774e+09
#
#                                             geometry FechaEncuesta  \
# 0  MULTIPOLYGON (((930273.425 4714737.743, 930147...    30/04/2023
# ...

# %%
injuries_provinces = pd.DataFrame(merge.groupby(['abbreviation']).size())
injuries_provinces.head()
injuries_provinces.columns
# Out:
# RangeIndex(start=0, stop=1, step=1)

# %%
# Ordena el DataFrame en orden descendente por la columna de recuentos
injuries_provinces_sorted = injuries_provinces.sort_values(by=0, ascending=False)

# Muestra las 5 filas con los valores más altos
top_5_injuries = injuries_provinces_sorted.head(5)

print(top_5_injuries)
# Out:
#                   0
# abbreviation
# RM            17331
# MI            12208
# TO             8289
# GE             7505
# NAPOLI         7456

# %%
# Obtener la forma (shape) del DataFrame
tamano_dataset = data3.shape

# Imprimir el resultado
print(f'Tamaño del dataset: {tamano_dataset}')
# Out:
# Tamaño del dataset: (262965, 41)

# %%
injuries_provinces.reset_index(level=0, inplace=True)

# %%
injuries_provinces.columns = ['abbreviation', 'Número de accidentes']

# %%
injuries_map = italy.merge(injuries_provinces, on='abbreviation', how='right')

# %%
# Number of injuries by province
fig, ax = plt.subplots(1, figsize=(5, 5))
col = 'Número de accidentes'
ax.set_title(
col, 
fontdict={'fontsize':'15', 'fontweight':'3'}, 
color='#14295d', 
fontfamily='monospace')
injuries_map.plot(
ax=ax,
column=col,
cmap='Reds',
label='',
legend=True,
categorical=False
).axis('off')
# Out:
# (263342.40726, 1361952.9959399996, 3869523.912790001, 5284614.59661)

# %%
provincia_cnt = np.round(data3['abbreviation'].value_counts(normalize=True) * 100)
hv.Bars(provincia_cnt).opts(title="Porcentaje por Provincia", color="#4169E1", xlabel="Provincias", ylabel="Porcentaje", yformatter='%d%%')\
                .opts(opts.Bars(width=500, height=300,tools=['hover'],show_grid=False))\
            * hv.Text('MI', 4, f"{int(provincia_cnt.loc['MI'])}%")\
            * hv.Text('RM', 4, f"{int(provincia_cnt.loc['RM'])}%")\
            * hv.Text('TO', 3.3, f"{int(provincia_cnt.loc['TO'])}%")\
            * hv.Text('GE', 3.3, f"{int(provincia_cnt.loc['GE'])}%")\
            * hv.Text('FI', 3.3, f"{int(provincia_cnt.loc['FI'])}%")\
            * hv.Text('NAPOLI', 3.3, f"{int(provincia_cnt.loc['NAPOLI'])}%")
# Out:
# :Overlay
#    .Bars.I   :Bars   [abbreviation]   (proportion)
#    .Text.I   :Text   [x,y]
#    .Text.II  :Text   [x,y]
#    .Text.III :Text   [x,y]
#    .Text.IV  :Text   [x,y]
#    .Text.V   :Text   [x,y]
#    .Text.VI  :Text   [x,y]

# %%
italy2 = gpd.read_file('Reg01012021_g_WGS84.shp') # region files

# %%
data3.Region[data3.Region == 'Friuli-Venezia Giulia'] = 'Friuli Venezia Giulia'
data3.Region[data3.Region == "Valle d'Aosta/Vallée d'Aoste"] = "Valle d'Aosta"
data3.Region[data3.Region == 'Trentino-Alto Adige/Südtirol'] = 'Trentino-Alto Adige'

# %%
italy2 = italy2.rename(columns = {'DEN_REG':'Region'})
italy2.columns
# Out:
# Index(['COD_RIP', 'COD_REG', 'Region', 'Shape_Leng', 'Shape_Area', 'geometry'], dtype='object')

# %%
merge = italy2.merge(data3, on='Region', how='right')

# %%
injuries_regions = pd.DataFrame(merge.groupby(['Region']).size())

# %%
injuries_regions.reset_index(level=0, inplace=True)

# %%
injuries_regions.columns = ['Region', 'Número de accidentes']

# %%
injuries_map = italy2.merge(injuries_regions, on='Region', how='right')

# %%
fig, ax = plt.subplots(1, figsize=(5, 5))
col = 'Número de accidentes'
ax.set_title(
col, 
fontdict={'fontsize':'15', 'fontweight':'3'}, 
color='#14295d', 
fontfamily='monospace')
injuries_map.plot(
ax=ax,
column=col,
cmap='Reds',
label='',
legend=True,
categorical=False
).axis('off')
# Out:
# (263342.40726, 1361952.9959399996, 3869523.912790001, 5284614.59661)

# %%
region_cnt = np.round(data3['Region'].value_counts(normalize=True) * 100)
hv.Bars(region_cnt).opts(title="Porcentaje por Región", color="#4169E1", xlabel="Región", ylabel="Porcentaje", yformatter='%d%%')\
                .opts(opts.Bars(width=500, height=300,tools=['hover'],show_grid=False))\
            * hv.Text('Lombardia', 5, f"{int(region_cnt.loc['Lombardia'])}%")\
            * hv.Text('Emilia-Romagna', 5, f"{int(region_cnt.loc['Emilia-Romagna'])}%")\
            * hv.Text('Veneto', 5, f"{int(region_cnt.loc['Veneto'])}%")\
            * hv.Text('Piemonte', 5, f"{int(region_cnt.loc['Piemonte'])}%")\
            * hv.Text('Toscana', 5, f"{int(region_cnt.loc['Toscana'])}%")\
            * hv.Text('Lazio', 5, f"{int(region_cnt.loc['Lazio'])}%")
# Out:
# :Overlay
#    .Bars.I   :Bars   [Region]   (proportion)
#    .Text.I   :Text   [x,y]
#    .Text.II  :Text   [x,y]
#    .Text.III :Text   [x,y]
#    .Text.IV  :Text   [x,y]
#    .Text.V   :Text   [x,y]
#    .Text.VI  :Text   [x,y]

# %%
# Ordena el DataFrame en orden descendente por la columna de recuentos
injuries_regions_sorted = injuries_regions.sort_values(by='Número de accidentes', ascending=False)

# Muestra las 5 filas con los valores más altos
top_5_injuries = injuries_regions_sorted.head(5)

print(top_5_injuries)
# Out:
#             Region  Número de accidentes
# 8        Lombardia                 38393
# 4   Emilia-Romagna                 28633
# 19          Veneto                 27727
# 15         Toscana                 24384
# 6            Lazio                 22086

# %%
regiones = {'Abruzzo', 'Basilicata', 'Calabria', 'Campania', 'Emilia-Romagna', 'Friuli-Venezia Giulia', 'Lazio', 
            'Liguria', 'Lombardia', 'Marche', 'Molise', 'Piemonte', 'Puglia', 'Sardegna', 'Sicilia', 'Toscana', 
            'Trentino-Alto Adige/Südtirol', 'Umbria', "Valle d'Aosta/Vallée d'Aoste", 'Veneto'}

divisiones = {
    'Noroccidental': {'Liguria', 'Lombardia', 'Piemonte', "Valle d'Aosta/Vallée d'Aoste"},
    'Nororiental': {'Emilia-Romagna', 'Friuli-Venezia Giulia', 'Trentino-Alto Adige/Südtirol', 'Veneto'},
    'Central': {'Lazio', 'Marche', 'Toscana', 'Umbria'},
    'Meridional': {'Abruzzo', 'Basilicata', 'Calabria', 'Campania', 'Molise', 'Puglia'},
    'Insular': {'Sardegna', 'Sicilia'}
}

# Mapear cada región a su división correspondiente
mapeo_divisiones = {}
for region in regiones:
    for division, regiones_division in divisiones.items():
        if region in regiones_division:
            mapeo_divisiones[region] = division
            break
# Supongamos que tienes un conjunto de datos llamado 'data' con una columna llamada 'Region'
# y deseas agregar una nueva columna llamada 'Division' con las divisiones especificadas.

data3['Zonas'] = data3['Region'].map(mapeo_divisiones)

# %%
Zonas_cnt = np.round(data3['Zonas'].value_counts(normalize=True) * 100)
hv.Bars(Zonas_cnt).opts(title="Accidentes por Zonas en Italia", color="royalblue", xlabel="Zonas Italia", ylabel="Percentage", yformatter='%d%%')\
                .opts(opts.Bars(width=500, height=300,tools=['hover'],show_grid=False))\
                * hv.Text('Noroccidental', 17, f"{int(Zonas_cnt.loc['Noroccidental'])}%")\
                * hv.Text('Nororiental', 17, f"{int(Zonas_cnt.loc['Nororiental'])}%")\
                * hv.Text('Meridional', 17, f"{int(Zonas_cnt.loc['Meridional'])}%")\
                * hv.Text('Central', 17, f"{int(Zonas_cnt.loc['Central'])}%")\
                * hv.Text('Insular', 4, f"{int(Zonas_cnt.loc['Insular'])}%")
# Out:
# :Overlay
#    .Bars.I   :Bars   [Zonas]   (proportion)
#    .Text.I   :Text   [x,y]
#    .Text.II  :Text   [x,y]
#    .Text.III :Text   [x,y]
#    .Text.IV  :Text   [x,y]
#    .Text.V   :Text   [x,y]

# %%
TipoActividadEconómica_cnt = np.round(data3['DescrTipoActividadEconómica'].value_counts(normalize=True) * 100)
hv.Bars(TipoActividadEconómica_cnt).opts(title="Tipo Actividad Económica", color="royalblue", xlabel="Sectors", ylabel="Percentage", yformatter='%d%%')\
                .opts(opts.Bars(width=500, height=300,tools=['hover'],show_grid=False))\
                * hv.Text('Artesanía', 17, f"{int(TipoActividadEconómica_cnt.loc['Artesanía'])}%")\
                * hv.Text('Industria', 17, f"{int(TipoActividadEconómica_cnt.loc['Industria'])}%")\
                * hv.Text('Otra Actividad', 17, f"{int(TipoActividadEconómica_cnt.loc['Otra Actividad'])}%")\
                * hv.Text('Terciario', 17, f"{int(TipoActividadEconómica_cnt.loc['Terciario'])}%")
# Out:
# :Overlay
#    .Bars.I   :Bars   [DescrTipoActividadEconómica]   (proportion)
#    .Text.I   :Text   [x,y]
#    .Text.II  :Text   [x,y]
#    .Text.III :Text   [x,y]
#    .Text.IV  :Text   [x,y]

# %%
SectorEconómico_cnt = np.round(data3['DescrSectorEconómico'].value_counts(normalize=True) * 100)
hv.Bars(SectorEconómico_cnt).opts(title="Sector Económico", color="royalblue", xlabel="Sector Económico", ylabel="Porcentaje", yformatter='%d%%')\
                .opts(opts.Bars(width=500, height=300,tools=['hover'], xrotation=30, show_grid=False))\
                * hv.Text('Agricultura y alimentación', 7, f"{int(SectorEconómico_cnt.loc['Agricultura y alimentación'])}%")\
                * hv.Text('Química, papel y cuero', 6, f"{int(SectorEconómico_cnt.loc['Química, papel y cuero'])}%")\
                * hv.Text('Construcción e instalaciones', 20, f"{int(SectorEconómico_cnt.loc['Construcción e instalaciones'])}%")\
                * hv.Text('Energía y comunicaciones', 5, f"{int(SectorEconómico_cnt.loc['Energía y comunicaciones'])}%")\
                * hv.Text('Madera y afines', 5, f"{int(SectorEconómico_cnt.loc['Madera y afines'])}%")\
                * hv.Text('Metales y maquinaria', 18, f"{int(SectorEconómico_cnt.loc['Metales y maquinaria'])}%")\
                * hv.Text('Minería, rocas y vidrio', 5, f"{int(SectorEconómico_cnt.loc['Minería, rocas y vidrio'])}%")\
                * hv.Text('Textil y confección', 5, f"{int(SectorEconómico_cnt.loc['Textil y confección'])}%")\
                * hv.Text('Transporte y almacenamiento', 14, f"{int(SectorEconómico_cnt.loc['Transporte y almacenamiento'])}%")\
                * hv.Text('Actividades diversas', 28, f"{int(SectorEconómico_cnt.loc['Actividades diversas'])}%")
# Out:
# :Overlay
#    .Bars.I    :Bars   [DescrSectorEconómico]   (proportion)
#    .Text.I    :Text   [x,y]
#    .Text.II   :Text   [x,y]
#    .Text.III  :Text   [x,y]
#    .Text.IV   :Text   [x,y]
#    .Text.V    :Text   [x,y]
#    .Text.VI   :Text   [x,y]
#    .Text.VII  :Text   [x,y]
#    .Text.VIII :Text   [x,y]
#    .Text.IX   :Text   [x,y]
#    .Text.X    :Text   [x,y]

# %%
conteo_valores = data3['DescrSectorEconómico'].value_counts()

# Imprimir el resultado
print('Número de veces que aparece cada valor único en DescrSectorEconómico:')
conteo_valores.to_excel('conteo_valores_sectorEc.xlsx')
print(conteo_valores)
# Out:
# Número de veces que aparece cada valor único en DescrSectorEconómico:
# DescrSectorEconómico
# Actividades diversas            122172
# Construcción e instalaciones     43873
# Metales y maquinaria             35841
# Transporte y almacenamiento      26028
# Agricultura y alimentación       10565
# Química, papel y cuero            8747
# Madera y afines                   5620
# Minería, rocas y vidrio           4446
# Textil y confección               4328
# Energía y comunicaciones          1345
# Name: count, dtype: int64

# %%
# Contar cuántas veces aparece cada valor único en 'DescrSectorEconómico' dividido por género
conteo_por_genero = data3.groupby(['Género', 'DescrSectorEconómico']).size().unstack(fill_value=0)

# Imprimir el resultado
print('Número de veces que aparece cada valor único en DescrSectorEconómico dividido por género:')
print(conteo_por_genero)
# Out:
# Número de veces que aparece cada valor único en DescrSectorEconómico dividido por género:
# DescrSectorEconómico  Actividades diversas  Agricultura y alimentación  \
# Género
# F                                    59489                        2378
# M                                    62683                        8187
#
# DescrSectorEconómico  Construcción e instalaciones  Energía y comunicaciones  \
# Género
# F                                              241                        44
# M                                            43632                      1301
#
# DescrSectorEconómico  Madera y afines  Metales y maquinaria  \
# Género
# F                                 277                  1784
# M                                5343                 34057
#
# DescrSectorEconómico  Minería, rocas y vidrio  Química, papel y cuero  \
# Género
# F                                         277                    1229
# ...

# %%
Género_cnt = np.round(data3['Género'].value_counts(normalize=True) * 100)
hv.Bars(Género_cnt).opts(title="Género", color="royalblue", xlabel="Género", ylabel="Porcentaje", yformatter='%d%%')\
                .opts(opts.Bars(width=500, height=300,tools=['hover'],show_grid=False))\
                * hv.Text('M', 15, f"{int(Género_cnt.loc['M'])}%")\
                * hv.Text('F', 15, f"{int(Género_cnt.loc['F'])}%")
# Out:
# :Overlay
#    .Bars.I  :Bars   [Género]   (proportion)
#    .Text.I  :Text   [x,y]
#    .Text.II :Text   [x,y]

# %%
accidents_regions_gender = pd.DataFrame(merge.groupby(['Region','Género']).size())

# %%
accidents_regions_gender.reset_index(level=0, inplace=True)
accidents_regions_gender.reset_index(level=0, inplace=True)

# %%
accidents_regions_gender.columns = ['Género', 'Region', 'Número de Accidentes']

# %%
injuries_map = italy2.merge(accidents_regions_gender, on='Region', how='right')

# %%
injuries_map_F = injuries_map[injuries_map.Género == 'F']
injuries_map_M = injuries_map[injuries_map.Género == 'M']

# %%
injuries_map_F = injuries_map_F.rename(columns = {'Número de Accidentes':'Número de Accidentes Género = F'})
injuries_map_M = injuries_map_M.rename(columns = {'Número de Accidentes':'Número de Accidentes Género = M'})

# %%
fig = plt.figure(figsize=(14,5))

ax1 = fig.add_subplot(121)
col = 'Número de Accidentes Género = M'
ax1.set_title(col, 
fontdict={'fontsize':'15', 'fontweight':'3'}, 
color='#14295d', 
fontfamily='monospace')
ax1 = injuries_map_M.plot(
ax=ax1,
column=col,
cmap='Reds',
label='',
legend=True,
categorical=False
).axis('off')
ax2 = fig.add_subplot(122)
col = 'Número de Accidentes Género = F'
ax2.set_title(col, 
fontdict={'fontsize':'15', 'fontweight':'3'}, 
color='#14295d', 
fontfamily='monospace')
ax2 = injuries_map_F.plot(
ax=ax2,
column=col,
cmap='Reds',
label='',
legend=True,
categorical=False
).axis('off')
plt.show()

# %%
# Ordenar los datos
year_counts = data3['Año'].value_counts(normalize=True).reindex(range(2018, 2023)) * 100
month_counts = data3['Mes'].value_counts(normalize=True).reindex(range(1, 13)) * 100
day_counts = data3['DiaMes'].value_counts(normalize=True).reindex(range(1, 32)) * 100
weekdays = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
weekday_counts = data3['DiaSemana'].value_counts(normalize=True).reindex(weekdays) * 100

# Crea gráficos de barras con HoloViews para cada métrica
year_bars = hv.Bars(year_counts).opts(title="Porcentaje de Accidentes por Año", color="royalblue", xlabel="Año")
month_bars = hv.Bars(month_counts).opts(title="Porcentaje de Accidentes por Mes", color="royalblue", xlabel="Mes")
day_bars = hv.Bars(day_counts).opts(title="Porcentaje de Accidentes por Día del Mes", color="royalblue", xlabel="Día del Mes")
weekday_bars = hv.Bars(weekday_counts).opts(title="Porcentaje de Accidentes por Día Semana", color="royalblue", xlabel="Día de la Semana")

# Mostrar los cuatro gráficos separados uno al lado del otro
(year_bars + month_bars + day_bars + weekday_bars).opts(
    opts.Bars(width=400, height=300, tools=['hover'], show_grid=False, ylabel="Porcentaje", yformatter='%d%%', bgcolor='white')
).cols(2)  # Dos columnas para organizar los gráficos en dos filas
# Out:
# :Layout
#    .Bars.I   :Bars   [Año]   (proportion)
#    .Bars.II  :Bars   [Mes]   (proportion)
#    .Bars.III :Bars   [DiaMes]   (proportion)
#    .Bars.IV  :Bars   [DiaSemana]   (proportion)

# %%
ModalidadAccidente_ = {'N': 'No', 'S':'Sí'}
                           
data3['ModalidadAccidente']=data3['ModalidadAccidente'].map(ModalidadAccidente_)

ImplicaciónMedioTransporte_ = {'N': 'No', 'S':'Sí'}
                           
data3['ImplicaciónMedioTransporte']=data3['ImplicaciónMedioTransporte'].map(ImplicaciónMedioTransporte_)

# %%
ModalidadAccidente_cnt = np.round(data3['ModalidadAccidente'].value_counts(normalize=True) * 100)
hv.Bars(ModalidadAccidente_cnt).opts(title="Modalidad Accidente", color="royalblue", xlabel="Modalidad Accidente", ylabel="Porcentaje", yformatter='%d%%')\
                .opts(opts.Bars(width=500, height=300,tools=['hover'],show_grid=False))\
                * hv.Text('Sí', 25, f"{int(ModalidadAccidente_cnt.loc['Sí'])}%")\
                * hv.Text('No', 25, f"{int(ModalidadAccidente_cnt.loc['No'])}%")
# Out:
# :Overlay
#    .Bars.I  :Bars   [ModalidadAccidente]   (proportion)
#    .Text.I  :Text   [x,y]
#    .Text.II :Text   [x,y]

# %%
ImplicaciónMedioTransporte_cnt = np.round(data3['ImplicaciónMedioTransporte'].value_counts(normalize=True) * 100)
hv.Bars(ImplicaciónMedioTransporte_cnt).opts(title="Implicación Medio Transporte", color="royalblue", xlabel="Implicación Medio Transporte", ylabel="Porcentaje", yformatter='%d%%')\
                .opts(opts.Bars(width=500, height=300,tools=['hover'],show_grid=False))\
                * hv.Text('Sí', 25, f"{int(ImplicaciónMedioTransporte_cnt.loc['Sí'])}%")\
                * hv.Text('No', 25, f"{int(ImplicaciónMedioTransporte_cnt.loc['No'])}%")
# Out:
# :Overlay
#    .Bars.I  :Bars   [ImplicaciónMedioTransporte]   (proportion)
#    .Text.I  :Text   [x,y]
#    .Text.II :Text   [x,y]

# %%
# Calcular el porcentaje de todas las combinaciones posibles
total_combinations = len(data3)
percentage_data = data3.groupby(['ImplicaciónMedioTransporte', 'ModalidadAccidente']).size() / total_combinations * 100

# Crear un gráfico de barras apiladas
stacked_data = percentage_data.unstack()
ax = stacked_data.plot(kind='bar', stacked=True)

# Anotar con el porcentaje en cada barra
for p in ax.patches:
    width, height = p.get_width(), p.get_height()
    x, y = p.get_xy() 
    ax.annotate(f'{height:.2f}%', (x + width/2, y + height/2), ha='center', va='center', fontsize=8)

plt.xlabel('Implicación Medio Transporte')
plt.ylabel('Porcentaje')
plt.title('Combinaciones Implicación Medio Transporte y Modalidad de Accidente')
plt.legend(title='Camino Trabajo', loc='upper right')
plt.grid(False)
plt.show()

# %%
import holoviews as hv
from holoviews import opts

f = lambda x: np.round(x / x.sum() * 100)
em_gen = data3.groupby(['Género', 'DescrTipoActividadEconómica'])['DescrTipoActividadEconómica'].count().unstack().apply(f, axis=1)
bars = hv.Bars(pd.melt(em_gen.reset_index(), ['Género']), ['Género', 'DescrTipoActividadEconómica'], 'value')

# Configurar opciones
options = opts.Bars(
    title="Tipo de Actividad Económica por Género",
    width=800,
    height=300,
    tools=['hover'],
    show_grid=True,  # Desactivar cuadrícula
    xrotation=30,
    ylabel="Percentage",
    yformatter='%d%%',
    bgcolor='white'  # Establecer el fondo en blanco
)

# %%
f = lambda x: np.round(x / x.sum() * 100)
em_gen = data3.groupby(['Género', 'DescrSectorEconómico'])['DescrSectorEconómico'].count().unstack().apply(f, axis=1)
bars = hv.Bars(pd.melt(em_gen.reset_index(), ['Género']), ['Género', 'DescrSectorEconómico'], 'value')

# Modificación para rotar el texto en el eje X y ajustar el tamaño del texto
bars.opts(
    opts.Bars(
        title="Sector Económico por Género",
        width=800,
        height=300,
        tools=['hover'],
        show_grid=True,
        xrotation=30,
        ylabel="Percentage",
        yformatter='%d%%',
        xticks={'fontsize': '0.1pt'}  # Ajusta el tamaño del texto del eje x aquí
    )
)
# Out:
# :Bars   [Género,DescrSectorEconómico]   (value)

# %%
import matplotlib.pyplot as plt

conteo_grado_deterioro = data3['ClaseDeterioro'].value_counts()

# Crear un gráfico de tarta
plt.figure(figsize=(5, 5))
pie_chart = plt.pie(conteo_grado_deterioro, colors=plt.cm.Paired.colors)

# Mostrar el gráfico
plt.title('Distribución de ClaseDeterioro')
plt.legend(title='ClaseDeterioro', labels=[f'{index} ({percentage:.1f}%)' for index, percentage in zip(conteo_grado_deterioro.index, conteo_grado_deterioro / conteo_grado_deterioro.sum() * 100)], loc='upper right', bbox_to_anchor=(2, 1))
plt.show()

# %%
conteo_ClaseDeterioro = data3['ClaseDeterioro'].value_counts()

# Imprimir el resultado
print('Número de veces que aparece cada valor único en ClaseDeterioro:')
print(conteo_ClaseDeterioro)
# Out:
# Número de veces que aparece cada valor único en ClaseDeterioro:
# ClaseDeterioro
# def. micropermanentes                   144941
# def. entidad mínima                      93729
# def. menor gravedad media                17310
# def. mayor gravedad media                 5838
# macrodeficiencias permanentes              874
# macrodeficiencias anulan buena salud       273
# Name: count, dtype: int64

# %%
f = lambda x : np.round(x/x.sum() * 100)
ac_gen = data3.groupby(['Género','ClaseDeterioro'])['ClaseDeterioro'].count().unstack().apply(f, axis=1)
ac = hv.Bars(pd.melt(ac_gen.reset_index(), ['Género']), ['Género','ClaseDeterioro'], 'value')

    opts.Bars(
        title="Grado deterioro por género",
        width=800,
        height=300,
        tools=['hover'],
        show_grid=False,
        xrotation=30,
        ylabel="Percentage",
        yformatter='%d%%',
        xticks={'fontsize': '0.1pt'}  # Ajusta el tamaño del texto del eje x aquí
    )
)
# Out:
# :Bars   [Género,ClaseDeterioro]   (value)

# %%
# Contar cuántas veces aparece cada valor único en 'DescrSectorEconómico' dividido por género
conteo_por_genero = data3.groupby(['Género', 'DescrSectorEconómico']).size().unstack(fill_value=0)

# Imprimir el resultado
print('Número de veces que aparece cada valor único en DescrSectorEconómico dividido por género:')
conteo_por_genero.to_excel('conteo_por_genero.xlsx')
# Out:
# Número de veces que aparece cada valor único en DescrSectorEconómico dividido por género:

# %%
plt.figure(figsize=(6, 4))
sns.violinplot(x='GradoDeterioro', y='DescrSectorEconómico', data=data3)
plt.title('Diagrama de Violín de GradoDeterioro por SectorEconómico')
plt.grid(False)
plt.show()

# %%
# Filtrar casos donde 'Muerte' es igual a 1
muerte_df = data3[data3['Muerte'] == 1]

# Configurar el estilo de seaborn (opcional)
sns.set(style="whitegrid")

# Crear un gráfico de barras
plt.figure(figsize=(4.5, 2.7))
sns.countplot(x='ClaseDeterioro', data=muerte_df, palette='viridis')
# Rotar el texto del eje x a 30 grados
plt.xticks(rotation=90)
# Añadir etiquetas y título
plt.xlabel('Clase de Deterioro')
plt.ylabel('Número de Muertes')
plt.title('Distribución de Muertes por Clase de Deterioro')
plt.grid(False)

# Mostrar el gráfico
plt.show()

# %%
# Supongamos que 'data' es tu DataFrame original
# Aquí creas un DataFrame agrupado por 'Año', 'Región' y 'TipoActividadEconómica'
grouped_data = data3.groupby(['Año', 'Region', 'DescrSectorEconómico']).size().reset_index(name='Número de Accidentes')

grouped_data.head()
# Out:
#     Año   Region          DescrSectorEconómico  Número de Accidentes
# 0  2018  Abruzzo          Actividades diversas                   694
# 1  2018  Abruzzo    Agricultura y alimentación                    84
# 2  2018  Abruzzo  Construcción e instalaciones                   343
# 3  2018  Abruzzo      Energía y comunicaciones                     9
# 4  2018  Abruzzo               Madera y afines                    31

# %%
plt.figure(figsize=(8, 4))

# Gráfico de líneas para toda Italia
sns.lineplot(data=grouped_data, x='Año', y='Número de Accidentes', hue='DescrSectorEconómico', ci=None)

plt.title('Número de Accidentes por Año y Tipo de Sector Económico en Italia')
plt.xlabel('Año')
plt.ylabel('Número de Accidentes')
plt.legend(title='Tipo de Sector Económico', bbox_to_anchor=(1.05, 1), loc='upper left')

# Configuración del gráfico
plt.grid(False)  # Desactivar cuadrícula
plt.gca().set_facecolor('white')  # Establecer el fondo en blanco
plt.show()

# %%
grouped_data_2 = data3.groupby(['Año', 'Region']).size().reset_index(name='Número de Accidentes')

grouped_data_2.head()
# Out:
#     Año          Region  Número de Accidentes
# 0  2018         Abruzzo                  1650
# 1  2018      Basilicata                   599
# 2  2018        Calabria                  1692
# 3  2018        Campania                  3086
# 4  2018  Emilia-Romagna                  6722

# %%
# Filtrar y ordenar los datos para el año 2018
data_2018_top10 = grouped_data_2[(grouped_data_2['Año'] == 2018)].sort_values(by='Número de Accidentes', ascending=True).tail(10)

# Crear un gráfico de barras horizontales para el año 2018
plt.figure(figsize=(6, 3))
plt.barh(data_2018_top10['Region'], data_2018_top10['Número de Accidentes'], height=0.4, color='royalblue')  # Cambia el color a verde
plt.axvline(x=6000,color='red',lw=2,ls='--',alpha=1)
plt.title('2018 Top Regiones - Número Accidentes')

# Configuración del gráfico
plt.grid(False)  # Desactivar cuadrícula
plt.gca().set_facecolor('white')  # Establecer el fondo en blanco
plt.show()

# Filtrar y ordenar los datos para el año 2022
data_2022_top10 = grouped_data_2[(grouped_data_2['Año'] == 2022)].sort_values(by='Número de Accidentes', ascending=True).tail(10)

# Crear un gráfico de barras horizontales para el año 2022
plt.figure(figsize=(6, 3))
plt.barh(data_2022_top10['Region'], data_2022_top10['Número de Accidentes'], height=0.4, color='royalblue')  # Cambia el color a verde
plt.axvline(x=6000,color='red',lw=2,ls='--',alpha=1)
plt.title('2022 Top Regiones - Número Accidentes')

# Configuración del gráfico
plt.grid(False)  # Desactivar cuadrícula
plt.gca().set_facecolor('white')  # Establecer el fondo en blanco
plt.show()

# %%
grouped_data3 = data3.groupby(['ClaseDeterioro', 'DescrSectorEconómico']).size().reset_index(name='Número de Accidentes')

grouped_data3.head()
# Out:
#           ClaseDeterioro          DescrSectorEconómico  Número de Accidentes
# 0  def. micropermanentes          Actividades diversas                 69577
# 1  def. micropermanentes    Agricultura y alimentación                  5917
# 2  def. micropermanentes  Construcción e instalaciones                 20594
# 3  def. micropermanentes      Energía y comunicaciones                   747
# 4  def. micropermanentes               Madera y afines                  2954

# %%
# Suponiendo que ya tienes el DataFrame agrupado 'grouped_data'
plt.figure(figsize=(7, 4))

# Gráfico de líneas para toda Italia
sns.lineplot(data=grouped_data3, x='ClaseDeterioro', y='Número de Accidentes', hue='DescrSectorEconómico', ci=None)

plt.title('Número de Accidentes por Grado Deterioro y Tipo de Sector Económico en Italia')
plt.xlabel('Grado Deterioro')
plt.ylabel('Número de Accidentes')
plt.legend(title='Tipo de Sector Económico', bbox_to_anchor=(1.05, 1), loc='upper left')

# Rotar el texto del eje x a 30 grados
plt.xticks(rotation=15)


# Configuración del gráfico
plt.grid(False)  # Desactivar cuadrícula
plt.gca().set_facecolor('white')  # Establecer el fondo en blanco
plt.show()

# %%
data3 = data3[data3['Edad'] >= 16]

# %%
sns.histplot(x='Edad', hue='Género', data=data3, palette= 'viridis', multiple='stack', kde=True)
plt.title('Histograma de Edad coloreado por Género')
plt.grid(False)
plt.show()

# %%
cantidad_personas_edad_50 = (data3['Edad'] == 50).sum()

# Imprimir el resultado
print(f'Número de personas con Edad igual a 50: {cantidad_personas_edad_50}')
# Out:
# Número de personas con Edad igual a 50: 8918

# %%
grouped_data4 = data3.groupby(['Edad', 'Género']).size().reset_index(name='Número de Accidentes')
grouped_data4 = grouped_data4[grouped_data4['Edad'] != -1]
grouped_data4.head()
# Out:
#    Edad Género  Número de Accidentes
# 0    16      F                     9
# 1    16      M                    65
# 2    17      F                    32
# 3    17      M                   192
# 4    18      F                    60

# %%
# Crear el scatterplot

# Crear la figura con un tamaño específico
plt.figure(figsize=(5, 4))

sns.scatterplot(data=grouped_data4, 
                y='Número de Accidentes',
                x='Edad',
                hue='Género',
                palette='viridis')

# Configurar propiedades adicionales
plt.gca().set_facecolor('white')  # Configurar el color de fondo
plt.grid(False)  # Desactivar las cuadrículas

plt.show()

# %%
# Crear el scatterplot

# Crear la figura con un tamaño específico
plt.figure(figsize=(5, 4))

sns.scatterplot(data=grouped_data4, 
                y='Número de Accidentes',
                x='Edad',
                hue='Género',
                palette='viridis')

# Configurar propiedades adicionales
plt.gca().set_facecolor('white')  # Configurar el color de fondo
plt.grid(False)  # Desactivar las cuadrículas

plt.show()
